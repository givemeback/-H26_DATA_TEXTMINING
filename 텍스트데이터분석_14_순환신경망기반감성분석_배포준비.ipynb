# %%
from mylib.sentiment_analyzer import SentimentAnalyzer

sa = SentimentAnalyzer('./model/sa_movie_model.keras', './model/sa_movie_encoder.pkl')
reviews = [
    '이 영화 개꿀잼 ㅋㅋㅋ',
    '하품만 나온다',
    '이 영화 핵노잼 ㅠㅠ',
    '이딴게 영화냐 ㅉㅉ',
    '와 개쩐다',
    '감독 뭐하는 놈이냐',
    '정말 세계관 최강자들의 영화다'
]

for review in reviews:
    user_output, prob = sa.analyze_sentiment(review)
    print(f'{review} --> {user_output}({prob*100:.2f}%)')
# Out:
# 이 영화 개꿀잼 ㅋㅋㅋ --> 긍정(99.84%)
# 하품만 나온다 --> 부정(99.89%)
# 이 영화 핵노잼 ㅠㅠ --> 부정(99.98%)
# 이딴게 영화냐 ㅉㅉ --> 부정(100.00%)
# 와 개쩐다 --> 긍정(99.37%)
# 감독 뭐하는 놈이냐 --> 부정(99.92%)
# 정말 세계관 최강자들의 영화다 --> 부정(66.47%)
